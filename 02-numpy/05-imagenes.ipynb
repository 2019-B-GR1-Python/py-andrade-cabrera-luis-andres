# %%
import numpy as np
from scipy import ndimage
from scipy import misc

# %%
mapache = misc.face()
mapache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
mapache.shape
# Out:
# (768, 1024, 3)

# %%
type(mapache)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(mapache)
plt.show()

# %%
plt.imshow(mapache[::-1])
plt.show()

# %%
part_mapache_1, part_mapache_2 = np.split(mapache, 2)

# %%
plt.imshow(part_mapache_1)
plt.show()

# %%
plt.imshow(part_mapache_2)
plt.show()

# %%
"""
1. Blanco y negro
2. Sepia
3. Negativo
4. Separar en N valores y reordenarlo en la misma imagen.
5. Recortar en Diagonal
"""
# Out:
# '\n1. Blanco y negro\n2. Sepia\n3. Negativo\n4. Separar en N valores y reordenarlo en la misma imagen.\n5. Recortar en Diagonal\n'

# %%
mapache[0].shape
#plt.imshow(mapache[0])
#plt.show()
# Out:
# (1024, 3)

# %%
mapache_bw_b, mapache_bw_g, mapache_bw_r = np.split(mapache, 2)
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84]]], dtype=uint8)
